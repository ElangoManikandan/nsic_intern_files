# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("Laptop_price_prediction_dataset.csv")
df
# Out:
#       ID        Date   Brand Processor  RAM_GB  Storage_GB  Price_USD  \
# 0      1  2023-01-01      HP        i7      16         128    1694.17
# 1      2  2023-01-02    Acer        i7       4         256    1605.62
# 2      3  2023-01-03    Acer   Ryzen 9       4        1024     335.74
# 3      4  2023-01-04    Asus   Ryzen 7      32         512    1903.31
# 4      5  2023-01-05  Lenovo    M1 Pro       8        1024    1011.77
# ..   ...         ...     ...       ...     ...         ...        ...
# 495  496  2024-05-10    Dell        i3      16        1024    1720.60
# 496  497  2024-05-11    Acer   Ryzen 7      16         512    1423.25
# 497  498  2024-05-12    Acer        i9      16         128     563.90
# 498  499  2024-05-13    Dell        i3       4        1024     986.54
# 499  500  2024-05-14    Asus        i3      16         128    2065.27
#
#         Model
# 0        Envy
# 1      Aspire
# 2       Nitro
# 3         ROG
# 4     IdeaPad
# ..        ...
# 495       XPS
# ...

# %% [raw]
# Bar chart

# %%
df['Brand'].value_counts().plot(kind='bar')
plt.title('Count of Laptops per Brand')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [raw]
# Line plot

# %%
plt.figure(figsize=(10, 5))
avg_price_over_time = df.groupby('Date')['Price_USD'].mean()
plt.plot(avg_price_over_time.index, avg_price_over_time.values)
plt.title('Average Laptop Price Over Time')
plt.xlabel('Date')
plt.ylabel('Average Price (USD)')
plt.show()

# %% [raw]
# Scatter Plot

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['RAM_GB'], df['Price_USD'])
plt.title('RAM Size vs Price')
plt.xlabel('RAM (GB)')
plt.ylabel('Price (USD)')
plt.show()

# %% [raw]
# Histogram

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Price_USD'], bins=20, edgecolor='k', alpha=0.7)
plt.title('Distribution of Laptop Prices')
plt.xlabel('Price (USD)')
plt.ylabel('Frequency')
plt.show()

# %% [raw]
# Box plot

# %%
plt.figure(figsize=(10, 6))
df.boxplot(column='Price_USD', by='Brand', grid=False)
plt.title('Price Distribution per Brand')
plt.xlabel('Brand')
plt.ylabel('Price (USD)')
plt.suptitle('') 
plt.xticks(rotation=45)
plt.show()

# %% [raw]
# Pie chart

# %%
plt.figure(figsize=(10, 6))
brand_counts = df['Brand'].value_counts()
plt.pie(brand_counts, labels=brand_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Market Share of Each Brand')
plt.axis('equal')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df['Date'] = pd.to_datetime(df['Date'])

df['Price_USD'] = pd.to_numeric(df['Price_USD'], errors='coerce')

df.dropna(subset=['Date', 'Price_USD'], inplace=True)
plt.figure(figsize=(10, 8))
numerical_features = ['RAM_GB', 'Storage_GB', 'Price_USD']
corr = df[numerical_features].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
#Area map
plt.figure(figsize=(14, 8))
df_sorted = df.sort_values(by='Date')
plt.fill_between(df_sorted['Date'], df_sorted['Price_USD'], color='skyblue', alpha=0.4)
plt.plot(df_sorted['Date'], df_sorted['Price_USD'], color='Slateblue', alpha=0.6, linewidth=2)
plt.title('Price Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.show()
